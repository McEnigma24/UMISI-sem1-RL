# %% [markdown]
# [backend] PyTorch  |  urzadzenie: CPU
# Test krytyka V(s)  |  srodowisko: CartPole-v1  |  model: cartpole_single_network\cartpole_final.keras
#   oczekiwany wymiar obserwacji: 4
#
#   [pion, zerowe predkosci (srodek)]
#     s = [0., 0., 0., 0.]
#     V(s) = 99.9929
#
#   [szybkie przechylenie (duza predkosc katowa)]
#     s = [0.  , 0.  , 0.15, 2.5 ]
#     V(s) = 13.1541
#
#   [wozek blisko prawej krawedzi (x ~ +2.35)]
#     s = [2.35, 0.  , 0.  , 0.  ]
#     V(s) = 38.3546
#
#   [wozek blisko lewej krawedzi (x ~ -2.35)]
#     s = [-2.35,  0.  ,  0.  ,  0.  ]
#     V(s) = 97.1618
#
#   [pochylony pret, spokojny wozek]
#     s = [0.  , 0.  , 0.12, 0.  ]
#     V(s) = 99.9869
